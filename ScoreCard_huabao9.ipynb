# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sc_func import *

# %% [markdown]
# ## 数据导入

# %%
#花豹11月01-12-01
data_form1= pd.read_csv('D:\\python\\huabao\\tmp_score_huabao_variable0428.csv')
#诺亚点点17年1101-1201
#data_form1= pd.read_csv('D:\\python\\huabao\\tmp_score_nuoya_variable0426_3.csv')

# %%
data_form1.shape
data_form1[data_form1['type']==1].shape[0]/data_form1.shape[0]
# Out:
# 0.08393378773125608

# %%
#诺亚点点17年12/02-18年01/08
data_form2= pd.read_csv('D:\\python\\huabao\\tmp_score_nuoya_variable0426_1.csv')

# %%
data_form2.shape
# Out:
# (1994, 35)

# %%
data_form2[data_form2['type']==1].shape[0]/data_form2.shape[0]
# Out:
# 0.04714142427281846

# %%
#诺亚点点11月1-12月1
data_form3= pd.read_csv('D:\\python\\huabao\\tmp_score_nuoya_variable0426_3.csv')
data_form3.shape
data_form3[data_form3['type']==1].shape[0]/data_form3.shape[0]
# Out:
# 0.08286674132138858

# %%
#诺亚点点2018-02/10-02/25
data_form4= pd.read_csv('D:\\python\\huabao\\tmp_score_nuoya_variable0426_2.csv')

# %%
#data_form=data_form1.append(data_form2)
data_form=data_form1

# %%
data_form.shape
# Out:
# (15405, 59)

# %%
x_columns = [x for x in data_form.columns if x not in ['type']]
keep_list = x_columns
target = 'type'

# %%
#样本的bad_rate
data_form[data_form['type']==1].shape[0]/data_form.shape[0]
# Out:
# 0.08393378773125608

# %%
pi1=data_form[data_form['type']==1].shape[0]/data_form.shape[0]

# %% [markdown]
# ## 变量筛选

# %%
#相关性删除
df=data_form
corr=df.corr()

# %%
corr.columns
# Out:
# Index(['type', 'cs_size_s', 'cs_size_s_ctn_l_rel_m', 'cs_size_s_ctn_m_rel_m',
#        'cs_size_s_ctn_m_rel_l', 'cs_size_s_ctn_l_rel_l', 'cs', 'od',
#        'ls_od_b_6m', 'ls_od_b_1y', 'ls_od_b_2y', 'ls_od_f_1t', 'ls_od_f_3t',
#        'ls_od_f_6t', 'xc_behavior', 'xc_overloan', 'xc_overdue', 'xc_record',
#        'lp_p1_xc_behavior', 'lp_p1_xc_overloan', 'lp_p1_xc_overdue',
#        'lp_p1_xc_record', 'rv', 'rc_idname_multi', 'rc_relation_age',
#        'rc_relation_cnt_name_phone', 'rc_relation_multi', 'rc_relation_cnt',
#        'ls_cr', 'ls_cr_cl', 'ls_gp', 'ls_gp_cl', 'ls_nw', 'ls_nd',
#        'ld_gps5_od', 'ld_gps5_rc', 'ld_gps5_xc', 'ld_add5_od', 'ld_add5_rc',
#        'ld_add5_xc_ml', 'ld_add5_xc_m', 'lp_p1_ld_add5_od', 'lp_p1_ld_add5_rc',
#        'lp_p1_ld_add5_xc_ml', 'lp_p1_ld_add5_xc_m', 'cg_add5', 'bs_gps5',
#        'bs_add5_id6plus_dist_c', 'bs_add5_id6plus_dist_vf',
#        'bs_add5_id6plus_dist_vc', 'bs_add5_id6plus_dist_f',
#        'lp_p1_ld_idnbr_6plus_xcp', 'lp_p1_vl_idnbr', 'bd_addr_abn_apply',
#        'bd_gps5_abn_apply', 'bd_addr_abn_spend', 'bd_gps5_abn_spend',
#        'dist_gps5_abn_beh', 'dist_gps5_abn_spend'],
#       dtype='object')

# %%
type(corr.columns)
# Out:
# pandas.indexes.base.Index

# %%
x_columns = [x for x in corr.columns if x not in ['type']]
x_columns
# Out:
# ['cs_size_s',
#  'cs_size_s_ctn_l_rel_m',
#  'cs_size_s_ctn_m_rel_m',
#  'cs_size_s_ctn_m_rel_l',
#  'cs_size_s_ctn_l_rel_l',
#  'cs',
#  'od',
#  'ls_od_b_6m',
#  'ls_od_b_1y',
#  'ls_od_b_2y',
#  'ls_od_f_1t',
#  'ls_od_f_3t',
#  'ls_od_f_6t',
#  'xc_behavior',
#  'xc_overloan',
#  'xc_overdue',
#  'xc_record',
#  'lp_p1_xc_behavior',
#  'lp_p1_xc_overloan',
#  'lp_p1_xc_overdue',
#  'lp_p1_xc_record',
#  'rv',
#  'rc_idname_multi',
#  'rc_relation_age',
#  'rc_relation_cnt_name_phone',
#  'rc_relation_multi',
#  'rc_relation_cnt',
#  'ls_cr',
#  'ls_cr_cl',
#  'ls_gp',
#  'ls_gp_cl',
#  'ls_nw',
#  'ls_nd',
#  'ld_gps5_od',
#  'ld_gps5_rc',
#  'ld_gps5_xc',
#  'ld_add5_od',
#  'ld_add5_rc',
#  'ld_add5_xc_ml',
#  'ld_add5_xc_m',
#  'lp_p1_ld_add5_od',
#  'lp_p1_ld_add5_rc',
#  'lp_p1_ld_add5_xc_ml',
#  'lp_p1_ld_add5_xc_m',
#  'cg_add5',
#  'bs_gps5',
#  'bs_add5_id6plus_dist_c',
#  'bs_add5_id6plus_dist_vf',
#  'bs_add5_id6plus_dist_vc',
#  'bs_add5_id6plus_dist_f',
#  'lp_p1_ld_idnbr_6plus_xcp',
#  'lp_p1_vl_idnbr',
#  'bd_addr_abn_apply',
#  'bd_gps5_abn_apply',
#  'bd_addr_abn_spend',
#  'bd_gps5_abn_spend',
#  'dist_gps5_abn_beh',
#  'dist_gps5_abn_spend']

# %%
corr[abs(corr)>0.5]
# Out:
#                             type  cs_size_s  cs_size_s_ctn_l_rel_m  \
# type                         1.0        NaN                    NaN
# cs_size_s                    NaN   1.000000                    NaN
# cs_size_s_ctn_l_rel_m        NaN        NaN                    1.0
# cs_size_s_ctn_m_rel_m        NaN        NaN                    NaN
# cs_size_s_ctn_m_rel_l        NaN        NaN                    NaN
# cs_size_s_ctn_l_rel_l        NaN   0.634902                    NaN
# cs                           NaN   0.725802                    NaN
# od                           NaN        NaN                    NaN
# ls_od_b_6m                   NaN        NaN                    NaN
# ls_od_b_1y                   NaN        NaN                    NaN
# ls_od_b_2y                   NaN        NaN                    NaN
# ls_od_f_1t                   NaN        NaN                    NaN
# ls_od_f_3t                   NaN        NaN                    NaN
# ls_od_f_6t                   NaN        NaN                    NaN
# xc_behavior                  NaN        NaN                    NaN
# xc_overloan                  NaN        NaN                    NaN
# xc_overdue                   NaN        NaN                    NaN
# xc_record                    NaN        NaN                    NaN
# lp_p1_xc_behavior            NaN        NaN                    NaN
# lp_p1_xc_overloan            NaN        NaN                    NaN
# lp_p1_xc_overdue             NaN        NaN                    NaN
# lp_p1_xc_record              NaN        NaN                    NaN
# rv                           NaN        NaN                    NaN
# rc_idname_multi              NaN        NaN                    NaN
# rc_relation_age              NaN        NaN                    NaN
# rc_relation_cnt_name_phone   NaN        NaN                    NaN
# rc_relation_multi            NaN        NaN                    NaN
# rc_relation_cnt              NaN        NaN                    NaN
# ls_cr                        NaN        NaN                    NaN
# ls_cr_cl                     NaN        NaN                    NaN
# ls_gp                        NaN        NaN                    NaN
# ls_gp_cl                     NaN        NaN                    NaN
# ls_nw                        NaN        NaN                    NaN
# ls_nd                        NaN        NaN                    NaN
# ld_gps5_od                   NaN        NaN                    NaN
# ld_gps5_rc                   NaN        NaN                    NaN
# ld_gps5_xc                   NaN        NaN                    NaN
# ld_add5_od                   NaN        NaN                    NaN
# ld_add5_rc                   NaN        NaN                    NaN
# ld_add5_xc_ml                NaN        NaN                    NaN
# ld_add5_xc_m                 NaN        NaN                    NaN
# lp_p1_ld_add5_od             NaN        NaN                    NaN
# lp_p1_ld_add5_rc             NaN        NaN                    NaN
# lp_p1_ld_add5_xc_ml          NaN        NaN                    NaN
# lp_p1_ld_add5_xc_m           NaN        NaN                    NaN
# cg_add5                      NaN        NaN                    NaN
# bs_gps5                      NaN        NaN                    NaN
# bs_add5_id6plus_dist_c       NaN        NaN                    NaN
# bs_add5_id6plus_dist_vf      NaN        NaN                    NaN
# bs_add5_id6plus_dist_vc      NaN        NaN                    NaN
# bs_add5_id6plus_dist_f       NaN        NaN                    NaN
# lp_p1_ld_idnbr_6plus_xcp     NaN        NaN                    NaN
# lp_p1_vl_idnbr               NaN        NaN                    NaN
# bd_addr_abn_apply            NaN        NaN                    NaN
# bd_gps5_abn_apply            NaN        NaN                    NaN
# bd_addr_abn_spend            NaN        NaN                    NaN
# bd_gps5_abn_spend            NaN        NaN                    NaN
# dist_gps5_abn_beh            NaN        NaN                    NaN
# dist_gps5_abn_spend          NaN        NaN                    NaN
#
#                             cs_size_s_ctn_m_rel_m  cs_size_s_ctn_m_rel_l  \
# type                                          NaN                    NaN
# cs_size_s                                     NaN                    NaN
# cs_size_s_ctn_l_rel_m                         NaN                    NaN
# cs_size_s_ctn_m_rel_m                         1.0                    NaN
# cs_size_s_ctn_m_rel_l                         NaN                    1.0
# cs_size_s_ctn_l_rel_l                         NaN                    NaN
# cs                                            NaN                    NaN
# od                                            NaN                    NaN
# ls_od_b_6m                                    NaN                    NaN
# ls_od_b_1y                                    NaN                    NaN
# ls_od_b_2y                                    NaN                    NaN
# ls_od_f_1t                                    NaN                    NaN
# ls_od_f_3t                                    NaN                    NaN
# ls_od_f_6t                                    NaN                    NaN
# xc_behavior                                   NaN                    NaN
# xc_overloan                                   NaN                    NaN
# xc_overdue                                    NaN                    NaN
# xc_record                                     NaN                    NaN
# lp_p1_xc_behavior                             NaN                    NaN
# lp_p1_xc_overloan                             NaN                    NaN
# lp_p1_xc_overdue                              NaN                    NaN
# lp_p1_xc_record                               NaN                    NaN
# rv                                            NaN                    NaN
# rc_idname_multi                               NaN                    NaN
# rc_relation_age                               NaN                    NaN
# rc_relation_cnt_name_phone                    NaN                    NaN
# rc_relation_multi                             NaN                    NaN
# rc_relation_cnt                               NaN                    NaN
# ls_cr                                         NaN                    NaN
# ls_cr_cl                                      NaN                    NaN
# ls_gp                                         NaN                    NaN
# ls_gp_cl                                      NaN                    NaN
# ls_nw                                         NaN                    NaN
# ls_nd                                         NaN                    NaN
# ld_gps5_od                                    NaN                    NaN
# ld_gps5_rc                                    NaN                    NaN
# ld_gps5_xc                                    NaN                    NaN
# ld_add5_od                                    NaN                    NaN
# ld_add5_rc                                    NaN                    NaN
# ld_add5_xc_ml                                 NaN                    NaN
# ld_add5_xc_m                                  NaN                    NaN
# lp_p1_ld_add5_od                              NaN                    NaN
# lp_p1_ld_add5_rc                              NaN                    NaN
# lp_p1_ld_add5_xc_ml                           NaN                    NaN
# lp_p1_ld_add5_xc_m                            NaN                    NaN
# cg_add5                                       NaN                    NaN
# bs_gps5                                       NaN                    NaN
# bs_add5_id6plus_dist_c                        NaN                    NaN
# bs_add5_id6plus_dist_vf                       NaN                    NaN
# bs_add5_id6plus_dist_vc                       NaN                    NaN
# bs_add5_id6plus_dist_f                        NaN                    NaN
# lp_p1_ld_idnbr_6plus_xcp                      NaN                    NaN
# lp_p1_vl_idnbr                                NaN                    NaN
# bd_addr_abn_apply                             NaN                    NaN
# bd_gps5_abn_apply                             NaN                    NaN
# bd_addr_abn_spend                             NaN                    NaN
# bd_gps5_abn_spend                             NaN                    NaN
# dist_gps5_abn_beh                             NaN                    NaN
# dist_gps5_abn_spend                           NaN                    NaN
#
#                             cs_size_s_ctn_l_rel_l        cs        od  \
# type                                          NaN       NaN       NaN
# cs_size_s                                0.634902  0.725802       NaN
# cs_size_s_ctn_l_rel_m                         NaN       NaN       NaN
# cs_size_s_ctn_m_rel_m                         NaN       NaN       NaN
# cs_size_s_ctn_m_rel_l                         NaN       NaN       NaN
# cs_size_s_ctn_l_rel_l                    1.000000       NaN       NaN
# cs                                            NaN  1.000000       NaN
# od                                            NaN       NaN  1.000000
# ls_od_b_6m                                    NaN       NaN  0.706923
# ls_od_b_1y                                    NaN       NaN       NaN
# ls_od_b_2y                                    NaN       NaN       NaN
# ls_od_f_1t                                    NaN       NaN  0.865913
# ls_od_f_3t                                    NaN       NaN  0.661244
# ls_od_f_6t                                    NaN       NaN       NaN
# xc_behavior                                   NaN       NaN       NaN
# xc_overloan                                   NaN       NaN       NaN
# xc_overdue                                    NaN       NaN       NaN
# xc_record                                     NaN       NaN       NaN
# lp_p1_xc_behavior                             NaN       NaN       NaN
# lp_p1_xc_overloan                             NaN       NaN       NaN
# lp_p1_xc_overdue                              NaN       NaN       NaN
# lp_p1_xc_record                               NaN       NaN       NaN
# rv                                            NaN       NaN       NaN
# rc_idname_multi                               NaN       NaN       NaN
# rc_relation_age                               NaN       NaN       NaN
# rc_relation_cnt_name_phone                    NaN       NaN       NaN
# rc_relation_multi                             NaN       NaN       NaN
# rc_relation_cnt                               NaN       NaN       NaN
# ls_cr                                         NaN       NaN       NaN
# ls_cr_cl                                      NaN       NaN       NaN
# ls_gp                                         NaN       NaN       NaN
# ls_gp_cl                                      NaN       NaN       NaN
# ls_nw                                         NaN       NaN       NaN
# ls_nd                                         NaN       NaN       NaN
# ld_gps5_od                                    NaN       NaN       NaN
# ld_gps5_rc                                    NaN       NaN       NaN
# ld_gps5_xc                                    NaN       NaN       NaN
# ld_add5_od                                    NaN       NaN       NaN
# ld_add5_rc                                    NaN       NaN       NaN
# ld_add5_xc_ml                                 NaN       NaN       NaN
# ld_add5_xc_m                                  NaN       NaN       NaN
# lp_p1_ld_add5_od                              NaN       NaN       NaN
# lp_p1_ld_add5_rc                              NaN       NaN       NaN
# lp_p1_ld_add5_xc_ml                           NaN       NaN       NaN
# lp_p1_ld_add5_xc_m                            NaN       NaN       NaN
# cg_add5                                       NaN       NaN       NaN
# bs_gps5                                       NaN       NaN       NaN
# bs_add5_id6plus_dist_c                        NaN       NaN       NaN
# bs_add5_id6plus_dist_vf                       NaN       NaN       NaN
# bs_add5_id6plus_dist_vc                       NaN       NaN       NaN
# bs_add5_id6plus_dist_f                        NaN       NaN       NaN
# lp_p1_ld_idnbr_6plus_xcp                      NaN       NaN       NaN
# lp_p1_vl_idnbr                                NaN       NaN       NaN
# bd_addr_abn_apply                             NaN       NaN       NaN
# bd_gps5_abn_apply                             NaN       NaN       NaN
# bd_addr_abn_spend                             NaN       NaN       NaN
# bd_gps5_abn_spend                             NaN       NaN       NaN
# dist_gps5_abn_beh                             NaN       NaN       NaN
# dist_gps5_abn_spend                           NaN       NaN       NaN
#
#                             ls_od_b_6m  ls_od_b_1y         ...           \
# type                               NaN         NaN         ...
# cs_size_s                          NaN         NaN         ...
# cs_size_s_ctn_l_rel_m              NaN         NaN         ...
# cs_size_s_ctn_m_rel_m              NaN         NaN         ...
# cs_size_s_ctn_m_rel_l              NaN         NaN         ...
# cs_size_s_ctn_l_rel_l              NaN         NaN         ...
# cs                                 NaN         NaN         ...
# od                            0.706923         NaN         ...
# ls_od_b_6m                    1.000000    0.612273         ...
# ls_od_b_1y                    0.612273    1.000000         ...
# ls_od_b_2y                         NaN    0.577313         ...
# ls_od_f_1t                         NaN         NaN         ...
# ls_od_f_3t                    0.935384    0.654569         ...
# ls_od_f_6t                    0.612273    1.000000         ...
# xc_behavior                        NaN         NaN         ...
# xc_overloan                        NaN         NaN         ...
# xc_overdue                         NaN         NaN         ...
# xc_record                          NaN         NaN         ...
# lp_p1_xc_behavior                  NaN         NaN         ...
# lp_p1_xc_overloan                  NaN         NaN         ...
# lp_p1_xc_overdue                   NaN         NaN         ...
# lp_p1_xc_record                    NaN         NaN         ...
# rv                                 NaN         NaN         ...
# rc_idname_multi                    NaN         NaN         ...
# rc_relation_age                    NaN         NaN         ...
# rc_relation_cnt_name_phone         NaN         NaN         ...
# rc_relation_multi                  NaN         NaN         ...
# rc_relation_cnt                    NaN         NaN         ...
# ls_cr                              NaN         NaN         ...
# ls_cr_cl                           NaN         NaN         ...
# ls_gp                              NaN         NaN         ...
# ls_gp_cl                           NaN         NaN         ...
# ls_nw                              NaN         NaN         ...
# ls_nd                              NaN         NaN         ...
# ld_gps5_od                         NaN         NaN         ...
# ld_gps5_rc                         NaN         NaN         ...
# ld_gps5_xc                         NaN         NaN         ...
# ld_add5_od                         NaN         NaN         ...
# ld_add5_rc                         NaN         NaN         ...
# ld_add5_xc_ml                      NaN         NaN         ...
# ld_add5_xc_m                       NaN         NaN         ...
# lp_p1_ld_add5_od                   NaN         NaN         ...
# lp_p1_ld_add5_rc                   NaN         NaN         ...
# lp_p1_ld_add5_xc_ml                NaN         NaN         ...
# lp_p1_ld_add5_xc_m                 NaN         NaN         ...
# cg_add5                            NaN         NaN         ...
# bs_gps5                            NaN         NaN         ...
# bs_add5_id6plus_dist_c             NaN         NaN         ...
# bs_add5_id6plus_dist_vf            NaN         NaN         ...
# bs_add5_id6plus_dist_vc            NaN         NaN         ...
# bs_add5_id6plus_dist_f             NaN         NaN         ...
# lp_p1_ld_idnbr_6plus_xcp           NaN         NaN         ...
# lp_p1_vl_idnbr                     NaN         NaN         ...
# bd_addr_abn_apply                  NaN         NaN         ...
# bd_gps5_abn_apply                  NaN         NaN         ...
# bd_addr_abn_spend                  NaN         NaN         ...
# bd_gps5_abn_spend                  NaN         NaN         ...
# dist_gps5_abn_beh                  NaN         NaN         ...
# dist_gps5_abn_spend                NaN         NaN         ...
#
#                             bs_add5_id6plus_dist_vc  bs_add5_id6plus_dist_f  \
# type                                            NaN                     NaN
# cs_size_s                                       NaN                     NaN
# cs_size_s_ctn_l_rel_m                           NaN                     NaN
# cs_size_s_ctn_m_rel_m                           NaN                     NaN
# cs_size_s_ctn_m_rel_l                           NaN                     NaN
# cs_size_s_ctn_l_rel_l                           NaN                     NaN
# cs                                              NaN                     NaN
# od                                              NaN                     NaN
# ls_od_b_6m                                      NaN                     NaN
# ls_od_b_1y                                      NaN                     NaN
# ls_od_b_2y                                      NaN                     NaN
# ls_od_f_1t                                      NaN                     NaN
# ls_od_f_3t                                      NaN                     NaN
# ls_od_f_6t                                      NaN                     NaN
# xc_behavior                                     NaN                     NaN
# xc_overloan                                     NaN                     NaN
# xc_overdue                                      NaN                     NaN
# xc_record                                       NaN                     NaN
# lp_p1_xc_behavior                               NaN                     NaN
# lp_p1_xc_overloan                               NaN                     NaN
# lp_p1_xc_overdue                                NaN                     NaN
# lp_p1_xc_record                                 NaN                     NaN
# rv                                              NaN                     NaN
# rc_idname_multi                                 NaN                     NaN
# rc_relation_age                                 NaN                     NaN
# rc_relation_cnt_name_phone                      NaN                     NaN
# rc_relation_multi                               NaN                     NaN
# rc_relation_cnt                                 NaN                     NaN
# ls_cr                                           NaN                     NaN
# ls_cr_cl                                        NaN                     NaN
# ls_gp                                           NaN                     NaN
# ls_gp_cl                                        NaN                     NaN
# ls_nw                                           NaN                     NaN
# ls_nd                                           NaN                     NaN
# ld_gps5_od                                      NaN                     NaN
# ld_gps5_rc                                      NaN                     NaN
# ld_gps5_xc                                      NaN                     NaN
# ld_add5_od                                      NaN                     NaN
# ld_add5_rc                                      NaN                     NaN
# ld_add5_xc_ml                                   NaN                     NaN
# ld_add5_xc_m                                    NaN                     NaN
# lp_p1_ld_add5_od                                NaN                     NaN
# lp_p1_ld_add5_rc                                NaN                     NaN
# lp_p1_ld_add5_xc_ml                             NaN                     NaN
# lp_p1_ld_add5_xc_m                              NaN                     NaN
# cg_add5                                         NaN                     NaN
# bs_gps5                                         NaN                     NaN
# bs_add5_id6plus_dist_c                          NaN                     NaN
# bs_add5_id6plus_dist_vf                         NaN                     NaN
# bs_add5_id6plus_dist_vc                         1.0                     NaN
# bs_add5_id6plus_dist_f                          NaN                     1.0
# lp_p1_ld_idnbr_6plus_xcp                        NaN                     NaN
# lp_p1_vl_idnbr                                  NaN                     NaN
# bd_addr_abn_apply                               NaN                     NaN
# bd_gps5_abn_apply                               NaN                     NaN
# bd_addr_abn_spend                               NaN                     NaN
# bd_gps5_abn_spend                               NaN                     NaN
# dist_gps5_abn_beh                               NaN                     NaN
# dist_gps5_abn_spend                             NaN                     NaN
#
#                             lp_p1_ld_idnbr_6plus_xcp  lp_p1_vl_idnbr  \
# type                                             NaN             NaN
# cs_size_s                                        NaN             NaN
# cs_size_s_ctn_l_rel_m                            NaN             NaN
# cs_size_s_ctn_m_rel_m                            NaN             NaN
# cs_size_s_ctn_m_rel_l                            NaN             NaN
# cs_size_s_ctn_l_rel_l                            NaN             NaN
# cs                                               NaN             NaN
# od                                               NaN             NaN
# ls_od_b_6m                                       NaN             NaN
# ls_od_b_1y                                       NaN             NaN
# ls_od_b_2y                                       NaN             NaN
# ls_od_f_1t                                       NaN             NaN
# ls_od_f_3t                                       NaN             NaN
# ls_od_f_6t                                       NaN             NaN
# xc_behavior                                      NaN             NaN
# xc_overloan                                      NaN             NaN
# xc_overdue                                       NaN             NaN
# xc_record                                        NaN             NaN
# lp_p1_xc_behavior                                NaN             NaN
# lp_p1_xc_overloan                                NaN             NaN
# lp_p1_xc_overdue                                 NaN             NaN
# lp_p1_xc_record                                  NaN             NaN
# rv                                               NaN             NaN
# rc_idname_multi                                  NaN             NaN
# rc_relation_age                                  NaN             NaN
# rc_relation_cnt_name_phone                       NaN             NaN
# rc_relation_multi                                NaN             NaN
# rc_relation_cnt                                  NaN             NaN
# ls_cr                                            NaN             NaN
# ls_cr_cl                                         NaN             NaN
# ls_gp                                            NaN             NaN
# ls_gp_cl                                         NaN             NaN
# ls_nw                                            NaN             NaN
# ls_nd                                            NaN             NaN
# ld_gps5_od                                       NaN             NaN
# ld_gps5_rc                                       NaN             NaN
# ld_gps5_xc                                       NaN             NaN
# ld_add5_od                                       NaN             NaN
# ld_add5_rc                                       NaN             NaN
# ld_add5_xc_ml                                    NaN             NaN
# ld_add5_xc_m                                     NaN             NaN
# lp_p1_ld_add5_od                                 NaN             NaN
# lp_p1_ld_add5_rc                                 NaN             NaN
# lp_p1_ld_add5_xc_ml                              NaN             NaN
# lp_p1_ld_add5_xc_m                               NaN             NaN
# cg_add5                                          NaN             NaN
# bs_gps5                                          NaN             NaN
# bs_add5_id6plus_dist_c                           NaN             NaN
# bs_add5_id6plus_dist_vf                          NaN             NaN
# bs_add5_id6plus_dist_vc                          NaN             NaN
# bs_add5_id6plus_dist_f                           NaN             NaN
# lp_p1_ld_idnbr_6plus_xcp                         1.0             NaN
# lp_p1_vl_idnbr                                   NaN             1.0
# bd_addr_abn_apply                                NaN             NaN
# bd_gps5_abn_apply                                NaN             NaN
# bd_addr_abn_spend                                NaN             NaN
# bd_gps5_abn_spend                                NaN             NaN
# dist_gps5_abn_beh                                NaN             NaN
# dist_gps5_abn_spend                              NaN             NaN
#
#                             bd_addr_abn_apply  bd_gps5_abn_apply  \
# type                                      NaN                NaN
# cs_size_s                                 NaN                NaN
# cs_size_s_ctn_l_rel_m                     NaN                NaN
# cs_size_s_ctn_m_rel_m                     NaN                NaN
# cs_size_s_ctn_m_rel_l                     NaN                NaN
# cs_size_s_ctn_l_rel_l                     NaN                NaN
# cs                                        NaN                NaN
# od                                        NaN                NaN
# ls_od_b_6m                                NaN                NaN
# ls_od_b_1y                                NaN                NaN
# ls_od_b_2y                                NaN                NaN
# ls_od_f_1t                                NaN                NaN
# ls_od_f_3t                                NaN                NaN
# ls_od_f_6t                                NaN                NaN
# xc_behavior                               NaN                NaN
# xc_overloan                               NaN                NaN
# xc_overdue                                NaN                NaN
# xc_record                                 NaN                NaN
# lp_p1_xc_behavior                         NaN                NaN
# lp_p1_xc_overloan                         NaN                NaN
# lp_p1_xc_overdue                          NaN                NaN
# lp_p1_xc_record                           NaN                NaN
# rv                                        NaN                NaN
# rc_idname_multi                           NaN                NaN
# rc_relation_age                           NaN                NaN
# rc_relation_cnt_name_phone                NaN                NaN
# rc_relation_multi                         NaN                NaN
# rc_relation_cnt                           NaN                NaN
# ls_cr                                     NaN                NaN
# ls_cr_cl                                  NaN                NaN
# ls_gp                                     NaN                NaN
# ls_gp_cl                                  NaN                NaN
# ls_nw                                     NaN                NaN
# ls_nd                                     NaN                NaN
# ld_gps5_od                                NaN                NaN
# ld_gps5_rc                                NaN                NaN
# ld_gps5_xc                                NaN                NaN
# ld_add5_od                                NaN                NaN
# ld_add5_rc                                NaN                NaN
# ld_add5_xc_ml                             NaN                NaN
# ld_add5_xc_m                              NaN                NaN
# lp_p1_ld_add5_od                          NaN                NaN
# lp_p1_ld_add5_rc                          NaN                NaN
# lp_p1_ld_add5_xc_ml                       NaN                NaN
# lp_p1_ld_add5_xc_m                        NaN                NaN
# cg_add5                                   NaN                NaN
# bs_gps5                                   NaN                NaN
# bs_add5_id6plus_dist_c                    NaN                NaN
# bs_add5_id6plus_dist_vf                   NaN                NaN
# bs_add5_id6plus_dist_vc                   NaN                NaN
# bs_add5_id6plus_dist_f                    NaN                NaN
# lp_p1_ld_idnbr_6plus_xcp                  NaN                NaN
# lp_p1_vl_idnbr                            NaN                NaN
# bd_addr_abn_apply                         1.0                NaN
# bd_gps5_abn_apply                         NaN                NaN
# bd_addr_abn_spend                         NaN                NaN
# bd_gps5_abn_spend                         NaN                NaN
# dist_gps5_abn_beh                         NaN                NaN
# dist_gps5_abn_spend                       NaN                NaN
#
#                             bd_addr_abn_spend  bd_gps5_abn_spend  \
# type                                      NaN                NaN
# cs_size_s                                 NaN                NaN
# cs_size_s_ctn_l_rel_m                     NaN                NaN
# cs_size_s_ctn_m_rel_m                     NaN                NaN
# cs_size_s_ctn_m_rel_l                     NaN                NaN
# cs_size_s_ctn_l_rel_l                     NaN                NaN
# cs                                        NaN                NaN
# od                                        NaN                NaN
# ls_od_b_6m                                NaN                NaN
# ls_od_b_1y                                NaN                NaN
# ls_od_b_2y                                NaN                NaN
# ls_od_f_1t                                NaN                NaN
# ls_od_f_3t                                NaN                NaN
# ls_od_f_6t                                NaN                NaN
# xc_behavior                               NaN                NaN
# xc_overloan                               NaN                NaN
# xc_overdue                                NaN                NaN
# xc_record                                 NaN                NaN
# lp_p1_xc_behavior                         NaN                NaN
# lp_p1_xc_overloan                         NaN                NaN
# lp_p1_xc_overdue                          NaN                NaN
# lp_p1_xc_record                           NaN                NaN
# rv                                        NaN                NaN
# rc_idname_multi                           NaN                NaN
# rc_relation_age                           NaN                NaN
# rc_relation_cnt_name_phone                NaN                NaN
# rc_relation_multi                         NaN                NaN
# rc_relation_cnt                           NaN                NaN
# ls_cr                                     NaN                NaN
# ls_cr_cl                                  NaN                NaN
# ls_gp                                     NaN                NaN
# ls_gp_cl                                  NaN                NaN
# ls_nw                                     NaN                NaN
# ls_nd                                     NaN                NaN
# ld_gps5_od                                NaN                NaN
# ld_gps5_rc                                NaN                NaN
# ld_gps5_xc                                NaN                NaN
# ld_add5_od                                NaN                NaN
# ld_add5_rc                                NaN                NaN
# ld_add5_xc_ml                             NaN                NaN
# ld_add5_xc_m                              NaN                NaN
# lp_p1_ld_add5_od                          NaN                NaN
# lp_p1_ld_add5_rc                          NaN                NaN
# lp_p1_ld_add5_xc_ml                       NaN                NaN
# lp_p1_ld_add5_xc_m                        NaN                NaN
# cg_add5                                   NaN                NaN
# bs_gps5                                   NaN                NaN
# bs_add5_id6plus_dist_c                    NaN                NaN
# bs_add5_id6plus_dist_vf                   NaN                NaN
# bs_add5_id6plus_dist_vc                   NaN                NaN
# bs_add5_id6plus_dist_f                    NaN                NaN
# lp_p1_ld_idnbr_6plus_xcp                  NaN                NaN
# lp_p1_vl_idnbr                            NaN                NaN
# bd_addr_abn_apply                         NaN                NaN
# bd_gps5_abn_apply                         NaN                NaN
# bd_addr_abn_spend                         1.0                NaN
# bd_gps5_abn_spend                         NaN                NaN
# dist_gps5_abn_beh                         NaN                NaN
# dist_gps5_abn_spend                       NaN                NaN
#
#                             dist_gps5_abn_beh  dist_gps5_abn_spend
# type                                      NaN                  NaN
# cs_size_s                                 NaN                  NaN
# cs_size_s_ctn_l_rel_m                     NaN                  NaN
# cs_size_s_ctn_m_rel_m                     NaN                  NaN
# cs_size_s_ctn_m_rel_l                     NaN                  NaN
# cs_size_s_ctn_l_rel_l                     NaN                  NaN
# cs                                        NaN                  NaN
# od                                        NaN                  NaN
# ls_od_b_6m                                NaN                  NaN
# ls_od_b_1y                                NaN                  NaN
# ls_od_b_2y                                NaN                  NaN
# ls_od_f_1t                                NaN                  NaN
# ls_od_f_3t                                NaN                  NaN
# ls_od_f_6t                                NaN                  NaN
# xc_behavior                               NaN                  NaN
# xc_overloan                               NaN                  NaN
# xc_overdue                                NaN                  NaN
# xc_record                                 NaN                  NaN
# lp_p1_xc_behavior                         NaN                  NaN
# lp_p1_xc_overloan                         NaN                  NaN
# lp_p1_xc_overdue                          NaN                  NaN
# lp_p1_xc_record                           NaN                  NaN
# rv                                        NaN                  NaN
# rc_idname_multi                           NaN                  NaN
# rc_relation_age                           NaN                  NaN
# rc_relation_cnt_name_phone                NaN                  NaN
# rc_relation_multi                         NaN                  NaN
# rc_relation_cnt                           NaN                  NaN
# ls_cr                                     NaN                  NaN
# ls_cr_cl                                  NaN                  NaN
# ls_gp                                     NaN                  NaN
# ls_gp_cl                                  NaN                  NaN
# ls_nw                                     NaN                  NaN
# ls_nd                                     NaN                  NaN
# ld_gps5_od                                NaN                  NaN
# ld_gps5_rc                                NaN                  NaN
# ld_gps5_xc                                NaN                  NaN
# ld_add5_od                                NaN                  NaN
# ld_add5_rc                                NaN                  NaN
# ld_add5_xc_ml                             NaN                  NaN
# ld_add5_xc_m                              NaN                  NaN
# lp_p1_ld_add5_od                          NaN                  NaN
# lp_p1_ld_add5_rc                          NaN                  NaN
# lp_p1_ld_add5_xc_ml                       NaN                  NaN
# lp_p1_ld_add5_xc_m                        NaN                  NaN
# cg_add5                                   NaN                  NaN
# bs_gps5                                   NaN                  NaN
# bs_add5_id6plus_dist_c                    NaN                  NaN
# bs_add5_id6plus_dist_vf                   NaN                  NaN
# bs_add5_id6plus_dist_vc                   NaN                  NaN
# bs_add5_id6plus_dist_f                    NaN                  NaN
# lp_p1_ld_idnbr_6plus_xcp                  NaN                  NaN
# lp_p1_vl_idnbr                            NaN                  NaN
# bd_addr_abn_apply                         NaN                  NaN
# bd_gps5_abn_apply                         NaN                  NaN
# bd_addr_abn_spend                         NaN                  NaN
# bd_gps5_abn_spend                         NaN                  NaN
# dist_gps5_abn_beh                         NaN                  NaN
# dist_gps5_abn_spend                       NaN                  1.0
#
# [59 rows x 59 columns]

# %%
corr_delete（df,）

# %% [markdown]
# ## VAR BINNING RESULT 变量分组结果

# %%
#先平均分组看各变量的IV值
num_iv = pd.Series()
columns=list(data_form.columns)
for c in range(1,len(columns)):
         num_iv = num_iv.append(variable_binning(data_form, target,columns[c], 5,'iv'))
print(num_iv)
# Out:
# C:\Users\xiongjun\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\generic.py:3295: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)
# C:\Users\xiongjun\sc_func.py:120: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df['qt_binning'] = df[var].apply(lambda x: map_dict[x])
# cs_size_s                     8.891353e-04
# cs_size_s_ctn_l_rel_m         1.495510e-26
# cs_size_s_ctn_m_rel_m         1.495510e-26
# cs_size_s_ctn_m_rel_l         1.495510e-26
# cs_size_s_ctn_l_rel_l         1.495510e-26
# cs                            8.912923e-04
# od                            1.495510e-26
# ls_od_b_6m                    1.495510e-26
# ls_od_b_1y                    1.495510e-26
# ls_od_b_2y                    1.495510e-26
# ls_od_f_1t                    1.495510e-26
# ls_od_f_3t                    1.495510e-26
# ls_od_f_6t                    1.495510e-26
# xc_behavior                   1.495510e-26
# xc_overloan                   2.022444e-01
# xc_overdue                    1.495510e-26
# xc_record                     1.495510e-26
# lp_p1_xc_behavior             1.495510e-26
# lp_p1_xc_overloan             1.495510e-26
# lp_p1_xc_overdue              1.495510e-26
# lp_p1_xc_record               1.495510e-26
# rv                            1.495510e-26
# rc_idname_multi               1.495510e-26
# rc_relation_age               1.495510e-26
# rc_relation_cnt_name_phone    1.495510e-26
# rc_relation_multi             1.495510e-26
# rc_relation_cnt               1.495510e-26
# ls_cr                         1.495510e-26
# ls_cr_cl                      1.495510e-26
# ls_gp                         1.495510e-26
# ls_gp_cl                      1.495510e-26
# ls_nw                         1.495510e-26
# ls_nd                         1.495510e-26
# ld_gps5_od                    1.495510e-26
# ld_gps5_rc                    1.495510e-26
# ld_gps5_xc                    1.495510e-26
# ld_add5_od                    1.495510e-26
# ld_add5_rc                    1.495510e-26
# ld_add5_xc_ml                 2.014545e-03
# ld_add5_xc_m                  3.453917e-04
# lp_p1_ld_add5_od              1.495510e-26
# lp_p1_ld_add5_rc              1.495510e-26
# lp_p1_ld_add5_xc_ml           1.495510e-26
# lp_p1_ld_add5_xc_m            4.005853e-03
# cg_add5                       1.495510e-26
# bs_gps5                       1.495510e-26
# bs_add5_id6plus_dist_c        1.495510e-26
# bs_add5_id6plus_dist_vf       2.288090e-03
# bs_add5_id6plus_dist_vc       1.495510e-26
# bs_add5_id6plus_dist_f        1.495510e-26
# lp_p1_ld_idnbr_6plus_xcp      1.495510e-26
# lp_p1_vl_idnbr                1.495510e-26
# bd_addr_abn_apply             1.495510e-26
# bd_gps5_abn_apply             1.495510e-26
# bd_addr_abn_spend             1.495510e-26
# bd_gps5_abn_spend             1.495510e-26
# dist_gps5_abn_beh             1.495510e-26
# dist_gps5_abn_spend           1.495510e-26
# dtype: float64

# %% [markdown]
# ## 逐个变量分组观察IV、占比、分组比例

# %%
var_name = 'cs_size_s_ctn_m_rel_m' #变量
var_bin = variable_binning(data_form, target, var_name, [0], 'bins')
binning_plot(var_bin)
print(var_name,'变量的IV值为',var_bin['IV'].sum())
var_bin_cs=var_bin['WOE']
(var_bin).sort_values('Lbound')
# Out:
# C:\Users\xiongjun\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\generic.py:3295: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)
# C:\Users\xiongjun\sc_func.py:124: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df['qt_binning'] = var_bins_series(df[var], bins, side = side)
# cs_size_s_ctn_m_rel_m 变量的IV值为 0.00044018703466850795
#             Lbound  Ubound  Totalcnt  PctTotal  Y_count  n_Y_count     Y_pct  \
# qt_binning
# (-inf, 0]        0       0     14933  0.969361     1249      13684  0.965971
# (0, +inf)        1       1       472  0.030639       44        428  0.034029
#
#              n_Y_pct   Y_rate       WOE        IV
# qt_binning
# (-inf, 0]   0.969671  0.08364 -0.003824  0.000014
# (0, +inf)   0.030329  0.09322  0.115127  0.000426

# %%
var_name = 'cg_add5' #变量
var_bin = variable_binning(data_form, target, var_name, [0], 'bins')
binning_plot(var_bin)
print(var_name,'变量的IV值为',var_bin['IV'].sum())
var_bin_od=var_bin['WOE']
var_bin.sort_values('Lbound')
# Out:
# C:\Users\xiongjun\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\generic.py:3295: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)
# C:\Users\xiongjun\sc_func.py:124: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df['qt_binning'] = var_bins_series(df[var], bins, side = side)
# cg_add5 变量的IV值为 1.4215918162062287e-05
#             Lbound  Ubound  Totalcnt  PctTotal  Y_count  n_Y_count     Y_pct  \
# qt_binning
# (-inf, 0]        0       0     14973  0.971957     1256      13717  0.971384
# (0, +inf)        1       1       432  0.028043       37        395  0.028616
#
#             n_Y_pct    Y_rate       WOE            IV
# qt_binning
# (-inf, 0]   0.97201  0.083884 -0.000643  4.023371e-07
# (0, +inf)   0.02799  0.085648  0.022093  1.381358e-05

# %%
var_name = 'xc_overloan' #变量
var_bin = variable_binning(data_form, target, var_name, [0], 'bins')
binning_plot(var_bin)
print(var_name,'变量的IV值为',var_bin['IV'].sum())
var_bin_xc_behavior=var_bin['WOE']
var_bin.sort_values('Lbound')
# Out:
# C:\Users\xiongjun\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\generic.py:3295: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)
# C:\Users\xiongjun\sc_func.py:124: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df['qt_binning'] = var_bins_series(df[var], bins, side = side)
# xc_overloan 变量的IV值为 0.20224436738114063
#             Lbound  Ubound  Totalcnt  PctTotal  Y_count  n_Y_count     Y_pct  \
# qt_binning
# (-inf, 0]        0       0      9644  0.626031      546       9098  0.422274
# (0, +inf)        1       1      5761  0.373969      747       5014  0.577726
#
#             n_Y_pct    Y_rate       WOE        IV
# qt_binning
# (-inf, 0]    0.6447  0.056616 -0.423131  0.094115
# (0, +inf)    0.3553  0.129665  0.486136  0.108129

# %%
var_name = 'xc_overdue' #变量
var_bin = variable_binning(data_form, target, var_name, [0], 'bins')
binning_plot(var_bin)
print(var_name,'变量的IV值为',var_bin['IV'].sum())
var_bin_xc_overloan=var_bin['WOE']
var_bin.sort_values('Lbound')
# Out:
# C:\Users\xiongjun\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\generic.py:3295: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)
# C:\Users\xiongjun\sc_func.py:124: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df['qt_binning'] = var_bins_series(df[var], bins, side = side)
# xc_overdue 变量的IV值为 0.015636710369998173
#             Lbound  Ubound  Totalcnt  PctTotal  Y_count  n_Y_count     Y_pct  \
# qt_binning
# (-inf, 0]        0       0     14480  0.939955     1177      13303  0.910286
# (0, +inf)        1       1       925  0.060045      116        809  0.089714
#
#              n_Y_pct    Y_rate       WOE        IV
# qt_binning
# (-inf, 0]   0.942673  0.081285 -0.034960  0.001132
# (0, +inf)   0.057327  0.125405  0.447852  0.014504

# %%
var_name = 'xc_behavior' #变量
var_bin = variable_binning(data_form, target, var_name, [0], 'bins')
binning_plot(var_bin)
print(var_name,'变量的IV值为',var_bin['IV'].sum())
var_bin_xc_overdue=var_bin['WOE']
var_bin.sort_values('Lbound')
# Out:
# C:\Users\xiongjun\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\generic.py:3295: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)
# C:\Users\xiongjun\sc_func.py:124: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df['qt_binning'] = var_bins_series(df[var], bins, side = side)
# xc_behavior 变量的IV值为 0.018829032896290145
#             Lbound  Ubound  Totalcnt  PctTotal  Y_count  n_Y_count     Y_pct  \
# qt_binning
# (-inf, 0]        0       0     14422   0.93619     1167      13255  0.902552
# (0, +inf)        1       1       983   0.06381      126        857  0.097448
#
#              n_Y_pct    Y_rate       WOE        IV
# qt_binning
# (-inf, 0]   0.939272  0.080918 -0.039878  0.001464
# (0, +inf)   0.060728  0.128179  0.472904  0.017365

# %%
var_name = 'rc_idname_multi' #变量
var_bin = variable_binning(data_form, target, var_name, [0], 'bins')
binning_plot(var_bin)
print(var_name,'变量的IV值为',var_bin['IV'].sum())
var_bin_xc_record=var_bin['WOE']
var_bin.sort_values('Lbound')
# Out:
# C:\Users\xiongjun\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\generic.py:3295: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)
# C:\Users\xiongjun\sc_func.py:124: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df['qt_binning'] = var_bins_series(df[var], bins, side = side)
# rc_idname_multi 变量的IV值为 0.004941684472779158
#             Lbound  Ubound  Totalcnt  PctTotal  Y_count  n_Y_count     Y_pct  \
# qt_binning
# (-inf, 0]        0       0     15044  0.976566     1249      13795  0.965971
# (0, +inf)        1       1       361  0.023434       44        317  0.034029
#
#              n_Y_pct    Y_rate       WOE        IV
# qt_binning
# (-inf, 0]   0.977537  0.083023 -0.011903  0.000138
# (0, +inf)   0.022463  0.121884  0.415348  0.004804

# %%
var_name = 'rc_relation_multi' #变量
var_bin = variable_binning(data_form, target, var_name, [0], 'bins')
binning_plot(var_bin)
print(var_name,'变量的IV值为',var_bin['IV'].sum())
var_bin_rv=var_bin['WOE']
var_bin.sort_values('Lbound')
# Out:
# C:\Users\xiongjun\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\generic.py:3295: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)
# C:\Users\xiongjun\sc_func.py:124: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df['qt_binning'] = var_bins_series(df[var], bins, side = side)
# rc_relation_multi 变量的IV值为 0.008621865228510103
#             Lbound  Ubound  Totalcnt  PctTotal  Y_count  n_Y_count    Y_pct  \
# qt_binning
# (-inf, 0]        0       0     15033  0.975852     1243      13790  0.96133
# (0, +inf)        1       1       372  0.024148       50        322  0.03867
#
#              n_Y_pct    Y_rate       WOE        IV
# qt_binning
# (-inf, 0]   0.977183  0.082685 -0.016355  0.000259
# (0, +inf)   0.022817  0.134409  0.527532  0.008363

# %%
var_name = 'rc_relation_cnt' #变量
var_bin = variable_binning(data_form, target, var_name, [0], 'bins')
binning_plot(var_bin)
print(var_name,'变量的IV值为',var_bin['IV'].sum())
var_bin.sort_values('Lbound')
# Out:
# C:\Users\xiongjun\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\generic.py:3295: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)
# C:\Users\xiongjun\sc_func.py:124: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df['qt_binning'] = var_bins_series(df[var], bins, side = side)
# rc_relation_cnt 变量的IV值为 0.010791199157047657
#             Lbound  Ubound  Totalcnt  PctTotal  Y_count  n_Y_count     Y_pct  \
# qt_binning
# (-inf, 0]        0       0     14829   0.96261     1219      13610  0.942769
# (0, +inf)        1       1       576   0.03739       74        502  0.057231
#
#              n_Y_pct    Y_rate       WOE        IV
# qt_binning
# (-inf, 0]   0.964427  0.082204 -0.022714  0.000492
# (0, +inf)   0.035573  0.128472  0.475525  0.010299

# %%
var_name = 'rc_idname_multi' #变量
var_bin = variable_binning(data_form, target, var_name, [0], 'bins')
binning_plot(var_bin)
print(var_name,'变量的IV值为',var_bin['IV'].sum())
var_bin_ls_cr=var_bin['WOE']
var_bin.sort_values('Lbound')
# Out:
# C:\Users\xiongjun\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\generic.py:3295: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)
# C:\Users\xiongjun\sc_func.py:124: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df['qt_binning'] = var_bins_series(df[var], bins, side = side)
# rc_idname_multi 变量的IV值为 0.004941684472779158
#             Lbound  Ubound  Totalcnt  PctTotal  Y_count  n_Y_count     Y_pct  \
# qt_binning
# (-inf, 0]        0       0     15044  0.976566     1249      13795  0.965971
# (0, +inf)        1       1       361  0.023434       44        317  0.034029
#
#              n_Y_pct    Y_rate       WOE        IV
# qt_binning
# (-inf, 0]   0.977537  0.083023 -0.011903  0.000138
# (0, +inf)   0.022463  0.121884  0.415348  0.004804

# %%
var_name = 'rc_relation_age' #变量
var_bin = variable_binning(data_form, target, var_name, [0], 'bins')
binning_plot(var_bin)
print(var_name,'变量的IV值为',var_bin['IV'].sum())
var_bin_ls_cr_cl=var_bin['WOE']
var_bin.sort_values('Lbound')
# Out:
# C:\Users\xiongjun\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\generic.py:3295: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)
# C:\Users\xiongjun\sc_func.py:124: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df['qt_binning'] = var_bins_series(df[var], bins, side = side)
# rc_relation_age 变量的IV值为 0.001714121371148161
#             Lbound  Ubound  Totalcnt  PctTotal  Y_count  n_Y_count     Y_pct  \
# qt_binning
# (-inf, 0]        0       0     15312  0.993963     1281      14031  0.990719
# (0, +inf)        1       1        93  0.006037       12         81  0.009281
#
#             n_Y_pct    Y_rate       WOE        IV
# qt_binning
# (-inf, 0]   0.99426  0.083660 -0.003568  0.000013
# (0, +inf)   0.00574  0.129032  0.480518  0.001701

# %%
var_name = 'ld_add5_rc' #变量
var_bin = variable_binning(data_form, target, var_name, [0], 'bins')
binning_plot(var_bin)
print(var_name,'变量的IV值为',var_bin['IV'].sum())
var_bin_ls_gp=var_bin['WOE']
var_bin.sort_values('Lbound')
# Out:
# C:\Users\xiongjun\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\generic.py:3295: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)
# C:\Users\xiongjun\sc_func.py:124: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df['qt_binning'] = var_bins_series(df[var], bins, side = side)
# ld_add5_rc 变量的IV值为 0.0017890440357584516
#             Lbound  Ubound  Totalcnt  PctTotal  Y_count  n_Y_count     Y_pct  \
# qt_binning
# (-inf, 0]        0       0     15359  0.997014     1286      14073  0.994586
# (0, +inf)        1       1        46  0.002986        7         39  0.005414
#
#              n_Y_pct    Y_rate       WOE        IV
# qt_binning
# (-inf, 0]   0.997236  0.083729 -0.002661  0.000007
# (0, +inf)   0.002764  0.152174  0.672409  0.001782

# %%
var_name = 'ld_gps5_rc' #变量
var_bin = variable_binning(data_form, target, var_name, [0], 'bins')
binning_plot(var_bin)
print(var_name,'变量的IV值为',var_bin['IV'].sum())
var_bin_ls_gp_cl=var_bin['WOE']
var_bin.sort_values('Lbound')
# Out:
# C:\Users\xiongjun\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\generic.py:3295: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)
# C:\Users\xiongjun\sc_func.py:124: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df['qt_binning'] = var_bins_series(df[var], bins, side = side)
# ld_gps5_rc 变量的IV值为 0.001937905818563798
#             Lbound  Ubound  Totalcnt  PctTotal  Y_count  n_Y_count     Y_pct  \
# qt_binning
# (-inf, 0]        0       0     15286  0.992275     1278      14008  0.988399
# (0, +inf)        1       1       119  0.007725       15        104  0.011601
#
#             n_Y_pct    Y_rate       WOE        IV
# qt_binning
# (-inf, 0]   0.99263  0.083606 -0.004272  0.000018
# (0, +inf)   0.00737  0.126050  0.453720  0.001920

# %%
var_name = 'ls_gp' #变量
var_bin = variable_binning(data_form, target, var_name, [0], 'bins')
binning_plot(var_bin)
print(var_name,'变量的IV值为',var_bin['IV'].sum())
var_bin_ls_nd=var_bin['WOE']
var_bin.sort_values('Lbound')
# Out:
# C:\Users\xiongjun\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\generic.py:3295: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)
# C:\Users\xiongjun\sc_func.py:124: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df['qt_binning'] = var_bins_series(df[var], bins, side = side)
# ls_gp 变量的IV值为 0.0005471079258969413
#             Lbound  Ubound  Totalcnt  PctTotal  Y_count  n_Y_count     Y_pct  \
# qt_binning
# (-inf, 0]        0       0     15163  0.984291     1276      13887  0.986852
# (0, +inf)        1       1       242  0.015709       17        225  0.013148
#
#              n_Y_pct    Y_rate       WOE        IV
# qt_binning
# (-inf, 0]   0.984056  0.084152  0.002837  0.000008
# (0, +inf)   0.015944  0.070248 -0.192827  0.000539

# %%
var_name = 'ls_cr_cl' #变量
var_bin = variable_binning(data_form, target, var_name, [0], 'bins')
binning_plot(var_bin)
print(var_name,'变量的IV值为',var_bin['IV'].sum())
var_bin_ld_rc=var_bin['WOE']
var_bin.sort_values('Lbound')
# Out:
# C:\Users\xiongjun\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\generic.py:3295: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)
# C:\Users\xiongjun\sc_func.py:124: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df['qt_binning'] = var_bins_series(df[var], bins, side = side)
# ls_cr_cl 变量的IV值为 0.028694458848898978
#             Lbound  Ubound  Totalcnt  PctTotal  Y_count  n_Y_count     Y_pct  \
# qt_binning
# (-inf, 0]        0       0     12406  0.805323     1116      11290  0.863109
# (0, +inf)        1       1      2999  0.194677      177       2822  0.136891
#
#              n_Y_pct    Y_rate       WOE        IV
# qt_binning
# (-inf, 0]   0.800028  0.089956  0.075894  0.004787
# (0, +inf)   0.199972  0.059020 -0.378991  0.023907

# %%
var_name = 'ls_nd' #变量
var_bin = variable_binning(data_form, target, var_name, [0], 'bins')
binning_plot(var_bin)
print(var_name,'变量的IV值为',var_bin['IV'].sum())
var_bin_ld_xc=var_bin['WOE']
var_bin.sort_values('Lbound')
# Out:
# C:\Users\xiongjun\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\generic.py:3295: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)
# C:\Users\xiongjun\sc_func.py:124: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df['qt_binning'] = var_bins_series(df[var], bins, side = side)
# ls_nd 变量的IV值为 0.05174944012491718
#             Lbound  Ubound  Totalcnt  PctTotal  Y_count  n_Y_count     Y_pct  \
# qt_binning
# (-inf, 0]        0       0     12907  0.837845     1173      11734  0.907193
# (0, +inf)        1       1      2498  0.162155      120       2378  0.092807
#
#              n_Y_pct    Y_rate       WOE        IV
# qt_binning
# (-inf, 0]   0.831491  0.090881  0.087134  0.006596
# (0, +inf)   0.168509  0.048038 -0.596463  0.045153

# %%
var_name = 'ls_cr' #变量
var_bin = variable_binning(data_form, target, var_name, [0], 'bins')
binning_plot(var_bin)
print(var_name,'变量的IV值为',var_bin['IV'].sum())
var_bin_bs_gps5=var_bin['WOE']
var_bin.sort_values('Lbound')
# Out:
# C:\Users\xiongjun\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\generic.py:3295: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)
# C:\Users\xiongjun\sc_func.py:124: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df['qt_binning'] = var_bins_series(df[var], bins, side = side)
# ls_cr 变量的IV值为 0.07861322767769173
#             Lbound  Ubound  Totalcnt  PctTotal  Y_count  n_Y_count     Y_pct  \
# qt_binning
# (-inf, 0]        0       0     14414   0.93567     1272      13142  0.983759
# (0, +inf)        1       1       991   0.06433       21        970  0.016241
#
#              n_Y_pct    Y_rate       WOE        IV
# qt_binning
# (-inf, 0]   0.931264  0.088248  0.054838  0.002879
# (0, +inf)   0.068736  0.021191 -1.442713  0.075735

# %%
var_name = 'rv' #变量
var_bin = variable_binning(data_form, target, var_name, [0], 'bins')
binning_plot(var_bin)
print(var_name,'变量的IV值为',var_bin['IV'].sum())
var_bin_ls_bs_add5=var_bin['WOE']
var_bin.sort_values('Lbound')
# Out:
# C:\Users\xiongjun\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\generic.py:3295: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)
# C:\Users\xiongjun\sc_func.py:124: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df['qt_binning'] = var_bins_series(df[var], bins, side = side)
# rv 变量的IV值为 0.002854342287703637
#             Lbound  Ubound  Totalcnt  PctTotal  Y_count  n_Y_count     Y_pct  \
# qt_binning
# (-inf, 0]        0       0     14483  0.940149     1200      13283  0.928074
# (0, +inf)        1       1       922  0.059851       93        829  0.071926
#
#              n_Y_pct    Y_rate       WOE        IV
# qt_binning
# (-inf, 0]   0.941256  0.082856 -0.014103  0.000186
# (0, +inf)   0.058744  0.100868  0.202440  0.002668

# %% [markdown]
# ## 模型训练

# %%
import statsmodels.api as sm
from sklearn.metrics import roc_auc_score,roc_curve,auc
import matplotlib.pylab as plb

# %%
selected_var ={
    #'cs_size_s':[0],
    #'cs_size_s_ctn_l_rel_m':[0],
 'cs_size_s_ctn_m_rel_m':[0],
 #'cs_size_s_ctn_m_rel_l':[0],
 #'cs_size_s_ctn_l_rel_l':[0],
               #'od':[0],
                #'ls_od_b_1y':[0],
                #'ls_od_b_2y':[0],
                #'ls_od_f_6t':[0],
               'xc_behavior':[0],
               'xc_overloan':[0],
               #'lp_p1_xc_overloan':[0],
               'xc_overdue':[0],
               #'xc_record':[0],
               'rv':[0],
                'rc_idname_multi':[0],
                'rc_relation_age':[0],
                'rc_relation_multi':[0],
                'rc_relation_cnt':[0],
               'ls_cr':[0],
               'ls_cr_cl':[0],
               'ls_gp':[0],
               #'ls_gp_cl':[0],
               'ls_nd':[0],
                'ld_gps5_rc':[0],
'ld_add5_rc':[0],
#'ld_add5_xc_ml':[0],
#'ld_add5_xc_m':[0],
#'lp_p1_ld_add5_od':[0],
#'lp_p1_ld_add5_rc':[0],
                 'cg_add5':[0],
               #'bs_gps5':[0],
#'bs_add5_id6plus_dist_c':[0],
#'bs_add5_id6plus_dist_vf':[0],
#'bs_add5_id6plus_dist_vc':[0],
#'lp_p1_ld_idnbr_6plus_xcp':[0],
#'lp_p1_vl_idnbr':[0]
               
              }

# %%
#WOE变换
WOE_train = WOE_mapping(data_form,selected_var, target)
train_X = WOE_train.drop(target, axis = 1)
train_X['constant'] = 1
train_Y = WOE_train[target]
# Out:
# C:\Users\xiongjun\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\generic.py:3295: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)
# C:\Users\xiongjun\sc_func.py:124: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df['qt_binning'] = var_bins_series(df[var], bins, side = side)

# %%
logit = sm.Logit(train_Y, train_X).fit()
logit_params=logit.params
logit.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.276780
#          Iterations 8
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                   type   No. Observations:                15405
# Model:                          Logit   Df Residuals:                    15388
# Method:                           MLE   Df Model:                           16
# Date:                Mon, 07 May 2018   Pseudo R-squ.:                 0.03987
# Time:                        14:30:18   Log-Likelihood:                -4263.8
# converged:                       True   LL-Null:                       -4440.9
#                                         LLR p-value:                 1.441e-65
# =========================================================================================
#                             coef    std err          z      P>|z|      [95.0% Conf. Int.]
# -----------------------------------------------------------------------------------------
# cs_size_s_ctn_m_rel_m     0.0341      1.385      0.025      0.980        -2.680     2.748
# xc_behavior               0.0208      0.204      0.102      0.919        -0.379     0.421
# xc_overloan               0.9056      0.068     13.323      0.000         0.772     1.039
# xc_overdue                0.6352      0.220      2.885      0.004         0.204     1.067
# rv                        0.4096      0.532      0.770      0.441        -0.633     1.452
# rc_idname_multi           0.5102      0.392      1.303      0.192        -0.257     1.278
# rc_relation_age           0.2475      0.682      0.363      0.717        -1.090     1.585
# rc_relation_multi         0.3756      0.307      1.222      0.222        -0.227     0.978
# rc_relation_cnt           0.3444      0.271      1.271      0.204        -0.187     0.875
# ls_cr                     0.8429      0.150      5.617      0.000         0.549     1.137
# ls_cr_cl                  0.4923      0.202      2.434      0.015         0.096     0.889
# ls_gp                     0.6325      1.309      0.483      0.629        -1.933     3.198
# ls_nd                     0.5361      0.158      3.393      0.001         0.226     0.846
# ld_gps5_rc                0.3672      0.620      0.592      0.554        -0.848     1.583
# ld_add5_rc                0.7077      0.633      1.118      0.264        -0.533     1.949
# cg_add5                   1.0057      7.774      0.129      0.897       -14.231    16.242
# constant                 -2.3905      0.030    -78.938      0.000        -2.450    -2.331
# =========================================================================================
# """

# %%
#KS值
predict_Y = logit.predict(train_X)
KS_calculation(train_Y,predict_Y, 40)
# Out:
# 0.28532169557691434

# %%
def evaluate_performance(all_target, predicted, toplot=True):
    fpr, tpr, thresholds = roc_curve(all_target, predicted)
    roc_auc = auc(fpr, tpr)
    ks = max(tpr-fpr)
    maxind = plb.find(tpr-fpr == ks)

    #?
    event_rate = sum(all_target) / 1.0 / all_target.shape[0]
    cum_total = tpr * event_rate + fpr * (1-event_rate)
    minind = plb.find(abs(cum_total - event_rate) == min(abs(cum_total - event_rate)))
    if minind.shape[0] > 0:
        minind = minind[0]

    print ('KS=' + str(round(ks, 3)) + ', AUC=' + str(round(roc_auc,2)) +', N='+str(predicted.shape[0]))
    print ('At threshold=' + str(round(event_rate, 3)) + ', TPR=' + str(round(tpr[minind],2)) + ', ' + str(int(round(tpr[minind]*event_rate*all_target.shape[0]))) + ' out of ' + str(int(round(event_rate*all_target.shape[0]))))
    print ('At threshold=' + str(round(event_rate, 3)) + ', FPR=' + str(round(fpr[minind],2)) + ', ' + str(int(round(fpr[minind]*(1.0-event_rate)*all_target.shape[0]))) + ' out of ' + str(int(round((1.0-event_rate)*all_target.shape[0]))))  
    
    # Score average by percentile
    binnum = 10
    ave_predict = np.zeros((binnum))
    ave_target = np.zeros((binnum))
    indices = np.argsort(predicted)
    binsize = int(round(predicted.shape[0]/1.0/binnum))
    for i in list(range(binnum)):
        startind = i*binsize
        endind = min(predicted.shape[0], (i+1)*binsize)
        ave_predict[i] = np.mean(predicted[indices[startind:endind]])
        ave_target[i] = np.mean(all_target[indices[startind:endind]])
    print ('Ave_target: ' + str(ave_target))
    print ('Ave_predicted: ' + str(ave_predict))
    
    if toplot:
        # KS plot
        plt.figure(figsize=(20,6))
        plt.subplot(1,3,1)
        plt.plot(fpr, tpr)
        plt.hold
        plt.plot([0,1],[0,1], color='k', linestyle='--', linewidth=2)
        plt.title('KS='+str(round(ks,2))+ ' AUC='+str(round(roc_auc,2)), fontsize=20)
        plt.plot([fpr[maxind], fpr[maxind]], [fpr[maxind], tpr[maxind]], linewidth=4, color='r')
        plt.plot([fpr[minind]], [tpr[minind]], 'k.', markersize=10)

        plt.xlim([0,1])
        plt.ylim([0,1])
        plt.xlabel('False positive', fontsize=20); plt.ylabel('True positive', fontsize=20);
        
        #print 'At threshold=' + str(round(event_rate, 3))
        #print str(round(fpr[minind],2))
        #print str(int(round(fpr[minind]*(1.0-event_rate)*all_target.shape[0])))
        #print str(int(round((1.0-event_rate)*all_target.shape[0]))) 
        
    
        # Score distribution score
        plt.subplot(1,3,2)
        #print predicted.columns
        plt.hist(predicted, bins=20)
        plt.hold
        plt.axvline(x=np.mean(predicted), linestyle='--')
        plt.axvline(x=np.mean(all_target), linestyle='--', color='g')
        plt.title('N='+str(all_target.shape[0])+' Tru='+str(round(np.mean(all_target),3))+' Pred='+str(round(np.mean(predicted),3)), fontsize=20)
        plt.xlabel('Target rate', fontsize=20)
        plt.ylabel('Count', fontsize=20)
        
        plt.subplot(1,3,3)
        plt.plot(ave_predict, 'b.-', label='Prediction', markersize=5)
        plt.hold
        plt.plot(ave_target, 'r.-', label='Truth', markersize=5)
        plt.legend(loc='lower right')
        plt.xlabel('Percentile', fontsize=20)
        plt.ylabel('Target rate', fontsize=20)
        
        plt.show()

    return ks

# %% [markdown]
# ## LIFT图和Gains图

# %%
plt.plot(Depth)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-659d7394785f> in <module>()
# ----> 1 plt.plot(Depth)
#       2 plt.show()
#
# NameError: name 'Depth' is not defined

# %%
fpr, tpr, thresholds = roc_curve(train_Y,predict_Y)
Depth,PV_plus,Lift=Lift_Gains(fpr,tpr,pi1)
# Out:
# C:\Users\xiongjun\sc_func.py:283: RuntimeWarning: invalid value encountered in true_divide
#   PV_plus=Ptp/Depth

# %%
#LIft图
plt.figure(figsize=(30,6))
plt.subplot(1,3,1)
#设置x轴范围
plt.xlim(0,1)
plt.ylim(1,3)
plt.title('LIFT')
plt.plot(Depth, Lift)

#Gains图
plt.subplot(1,3,2)
#设置x轴范围
plt.xlim(0,1)
plt.ylim(0.05,0.6)
plt.title('Gains')
plt.plot(Depth, PV_plus,color="m",linestyle="-")
plt.show()

# %%
len(thresholds)
# Out:
# 501

# %%
def KS_calculation_plot(y, y_pred, bin_num=20):
    '''
    Calculate KS
    '''
    df = pd.DataFrame()
    df['y'] = y
    df['y_pred'] = y_pred
    n_sample = df.shape[0]
    y_cnt = df['y'].sum()
    #向上取整
    bucket_sample = ceil(n_sample/bin_num)
    #df按y_pred进行排序
    df = df.sort_values('y_pred', ascending = False)
    df['group'] = [ceil(x/bucket_sample) for x in range(1, n_sample+1)]

    grouped = df.groupby('group')['y'].agg({'Totalcnt': 'count',
                                            'Y_rate': np.mean,
                                            'Y_pct': lambda x: np.sum(x / y_cnt),
                                            'n_Y_pct': lambda x: np.sum((1-x) / (n_sample-y_cnt))})
    grouped['Cum_Y_pct'] = grouped['Y_pct'].cumsum()
    grouped['Cum_nY_pct'] = grouped['n_Y_pct'].cumsum()
    grouped['KS'] = (grouped['Cum_Y_pct'] - grouped['Cum_nY_pct']).map(lambda x: abs(x))

    KS = grouped['KS'].max()
    
    plt.figure(figsize=(20,6))
    plt.subplot(1,3,1)
    plt.plot(grouped['Cum_Y_pct'])
    plt.hold
    plt.plot(grouped['Cum_nY_pct'])
    plt.show()
    return KS

# %%
KS_calculation_plot(train_Y,predict_Y, 40)
# Out:
# 0.25701020934282276

# %%
evaluate_performance(train_Y, predict_Y,toplot=True)
# Out:
# KS=0.257, AUC=0.65, N=15405
# At threshold=0.084, TPR=0.15, 191 out of 1293
# At threshold=0.084, FPR=0.08, 1078 out of 14112
# Ave_target: [ 0.02857143  0.04805195  0.0487013   0.05584416  0.06298701  0.06818182
#   0.09675325  0.12987013  0.1487013   0.1512987 ]
# Ave_predicted: [ 0.0259325   0.04640251  0.05945357  0.06345707  0.06345707  0.06538493
#   0.09002834  0.13206084  0.1340048   0.15846445]
# 0.25749802047655879

# %%
#ROC值
roc_auc_score(train_Y,predict_Y)
# Out:
# 0.65287993258659494

# %% [markdown]
# ## 打分

# %%
import math
score_data=data_form[['type']]
score_data['probability'] = predict_Y

#风险odds=15:1时，基本分数为500分
#风险翻倍时，即odds=15:2时，分数降低50分
B = 50/math.log(2, math.e)
A = 500 + B * math.log(1/15,math.e)

score_data['odds'] = (score_data['probability']/(1-score_data['probability']) ).apply(lambda x: math.log(x, math.e))
score_data['score'] = A - B * score_data['odds']
# Out:
# C:\Users\xiongjun\AppData\Local\Continuum\Anaconda3\lib\site-packages\ipykernel\__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# C:\Users\xiongjun\AppData\Local\Continuum\Anaconda3\lib\site-packages\ipykernel\__main__.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\xiongjun\AppData\Local\Continuum\Anaconda3\lib\site-packages\ipykernel\__main__.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
score_data['score'].sum()/score_data.shape[0]
# Out:
# 487.06485854764077

# %%
score_data[score_data['score']<=600].shape[0]
# Out:
# 15068

# %%
score_data[score_data['score']<=560].shape[0]/score_data.shape[0]
# Out:
# 0.9489776046738072

# %%
score_data[(score_data.score<=560) & (score_data.type==1)].shape[0]/score_data[score_data['score']<=560].shape[0]
# Out:
# 0.08748888432861344

# %%
#分数区间
score_data.score.hist()
plt.show()

# %%
#分数分段
var_name = 'score' #变量
bins=[460,480,500,530,550]
#bins=10
var_bin = variable_binning(score_data, target, var_name, bins, 'bins')
#var_bin.sort_values('Lbound')
# Out:
# C:\Users\xiongjun\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\generic.py:3295: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)
# C:\Users\xiongjun\sc_func.py:124: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df['qt_binning'] = var_bins_series(df[var], bins, side = side)

# %%
def binning_plot(df):
    '''
    plot Y_rate and bin_percent curves
    '''
    plt.figure(figsize=(16, 6))
    plt.subplot(121)
    df['Y_rate'].plot()
    plt.title('bins_bad_rate')

    plt.subplot(122)
    df['PctTotal'].plot.bar(secondary_y=True,alpha = 0.8, grid = False)
    plt.title('bins_cnt')
    
    
    plt.tight_layout()
    plt.show()

# %%
binning_plot(var_bin)

# %%
var_bin['Lift']=var_bin['Y_rate']/pi1
var_bin['Lift'].plot.bar(secondary_y=True,alpha = 0.8, grid = False)
plt.title('Lift')
plt.show()

# %%
var_bin
# Out:
#                  Lbound      Ubound  Totalcnt  PctTotal  Y_count  n_Y_count  \
# qt_binning
# (-inf, 460]  354.247561  459.876285      5016  0.325609      709       4307
# (460, 480]   460.169222  479.985665       558  0.036222       62        496
# (480, 500]   480.112102  499.527811      6273  0.407205      380       5893
# (500, 530]   500.457369  529.984968      1902  0.123466       92       1810
# (530, 550]   530.460018  549.959987       813  0.052775       34        779
# (550, +inf)  550.452284  632.740421       843  0.054722       16        827
#
#                 Y_pct   n_Y_pct    Y_rate       WOE        IV      Lift
# qt_binning
# (-inf, 460]  0.548337  0.305201  0.141348  0.585919  0.142458  1.684038
# (460, 480]   0.047951  0.035147  0.111111  0.310619  0.003977  1.323795
# (480, 500]   0.293890  0.417588  0.060577 -0.351289  0.043454  0.721725
# (500, 530]   0.071152  0.128260  0.048370 -0.589233  0.033650  0.576289
# (530, 550]   0.026295  0.055201  0.041820 -0.741590  0.021436  0.498255
# (550, +inf)  0.012374  0.058603  0.018980 -1.555156  0.071892  0.226129

# %% [markdown]
# ## 变量分组打分

# %%
selected_var ={
    #'cs_size_s':[0],
    #'cs_size_s_ctn_l_rel_m':[0],
 'cs_size_s_ctn_m_rel_m':[0],
 #'cs_size_s_ctn_m_rel_l':[0],
 #'cs_size_s_ctn_l_rel_l':[0],
               #'od':[0],
                #'ls_od_b_1y':[0],
                #'ls_od_b_2y':[0],
                #'ls_od_f_6t':[0],
               'xc_behavior':[0],
               'xc_overloan':[0],
               #'lp_p1_xc_overloan':[0],
               'xc_overdue':[0],
               #'xc_record':[0],
               'rv':[0],
                'rc_idname_multi':[0],
                'rc_relation_age':[0],
                'rc_relation_multi':[0],
                'rc_relation_cnt':[0],
               'ls_cr':[0],
               'ls_cr_cl':[0],
               'ls_gp':[0],
               #'ls_gp_cl':[0],
               'ls_nd':[0],
                'ld_gps5_rc':[0],
'ld_add5_rc':[0],
#'ld_add5_xc_ml':[0],
#'ld_add5_xc_m':[0],
#'lp_p1_ld_add5_od':[0],
#'lp_p1_ld_add5_rc':[0],
                 'cg_add5':[0],
               #'bs_gps5':[0],
#'bs_add5_id6plus_dist_c':[0],
#'bs_add5_id6plus_dist_vf':[0],
#'bs_add5_id6plus_dist_vc':[0],
#'lp_p1_ld_idnbr_6plus_xcp':[0],
#'lp_p1_vl_idnbr':[0]
               
              }
#各变量分组的WOE集合放在一个字典中
def var_woe_result(df, target, select_var):
    output_df = select_var
    var_list = list(select_var.keys())
    for i in var_list:
        output_df[i] = variable_binning(df, target, i,select_var.get(i), 'bins')['WOE'] #select_var.get(i)返回字典中键的关联值即分组的切割值bin
    return output_df

var_woe_result=var_woe_result(data_form,target,selected_var)
# Out:
# C:\Users\xiongjun\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\generic.py:3295: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)
# C:\Users\xiongjun\sc_func.py:124: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df['qt_binning'] = var_bins_series(df[var], bins, side = side)

# %%
#乘以模型参数得出变量分
variable_score=var_woe_result
var_list = list(var_woe_result.keys())
for i in var_list:
    variable_score[i] = var_woe_result.get(i)*logit_params[i]*B*(-1)

# %%
variable_score
# Out:
# {'cg_add5': qt_binning
#  (-inf, 0]    0.046682
#  (0, +inf)   -1.602735
#  Name: WOE, dtype: float64, 'cs_size_s_ctn_m_rel_m': qt_binning
#  (-inf, 0]    0.009416
#  (0, +inf)   -0.283521
#  Name: WOE, dtype: float64, 'ld_add5_rc': qt_binning
#  (-inf, 0]     0.135842
#  (0, +inf)   -34.325413
#  Name: WOE, dtype: float64, 'ld_gps5_rc': qt_binning
#  (-inf, 0]     0.113146
#  (0, +inf)   -12.017402
#  Name: WOE, dtype: float64, 'ls_cr': qt_binning
#  (-inf, 0]    -3.334128
#  (0, +inf)    87.716921
#  Name: WOE, dtype: float64, 'ls_cr_cl': qt_binning
#  (-inf, 0]    -2.694889
#  (0, +inf)    13.457458
#  Name: WOE, dtype: float64, 'ls_gp': qt_binning
#  (-inf, 0]   -0.129450
#  (0, +inf)    8.797163
#  Name: WOE, dtype: float64, 'ls_nd': qt_binning
#  (-inf, 0]    -3.369662
#  (0, +inf)    23.066427
#  Name: WOE, dtype: float64, 'rc_idname_multi': qt_binning
#  (-inf, 0]     0.438088
#  (0, +inf)   -15.287384
#  Name: WOE, dtype: float64, 'rc_relation_age': qt_binning
#  (-inf, 0]    0.063706
#  (0, +inf)   -8.580195
#  Name: WOE, dtype: float64, 'rc_relation_cnt': qt_binning
#  (-inf, 0]     0.564308
#  (0, +inf)   -11.814204
#  Name: WOE, dtype: float64, 'rc_relation_multi': qt_binning
#  (-inf, 0]     0.443178
#  (0, +inf)   -14.294326
#  Name: WOE, dtype: float64, 'rv': qt_binning
#  (-inf, 0]    0.416647
#  (0, +inf)   -5.980685
#  Name: WOE, dtype: float64, 'xc_behavior': qt_binning
#  (-inf, 0]    0.059725
#  (0, +inf)   -0.708262
#  Name: WOE, dtype: float64, 'xc_overdue': qt_binning
#  (-inf, 0]     1.601787
#  (0, +inf)   -20.519333
#  Name: WOE, dtype: float64, 'xc_overloan': qt_binning
#  (-inf, 0]    27.641547
#  (0, +inf)   -31.757482
#  Name: WOE, dtype: float64}

# %%
logit_params['constant']*B
# Out:
# -172.42799566935929

# %% [markdown]
# ## 模型基础分数

# %%
base_score=A-logit_params['constant']*B
base_score
# Out:
# 477.08346588893335

# %%
B
# Out:
# 72.13475204444818

# %%
A
# Out:
# 304.65547021957406

# %%
#打分详情下载
import math
score_data1=data_form[['type',
                'ls_od_b_1y',
                'ls_od_b_2y',
               'xc_overloan',
               'xc_overdue',
               'rv',
               'rc_idname_multi',
                'rc_relation_cnt',
               'ls_cr',
               'ls_cr_cl',
               'ls_gp',
               'ls_nd',
               'ld_xc',
               'bs_gps5']]
score_data1['probability'] = predict_Y

#风险odds=15:1时，基本分数为660分
#风险翻倍时，即odds=15:2时，分数降低50分
B = 50/math.log(2, math.e)
A = 500 + B * math.log(1/15,math.e)

score_data1['odds'] = (score_data['probability']/(1-score_data['probability']) ).apply(lambda x: math.log(x, math.e))
score_data1['score'] = A - B * score_data['odds']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-77-5ebf84f5694c> in <module>()
#      14                'ls_nd',
#      15                'ld_xc',
# ---> 16                'bs_gps5']]
#      17 score_data1['probability'] = predict_Y
#      18
#
# C:\Users\xiongjun\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2051         if isinstance(key, (Series, np.ndarray, Index, list)):
#    2052             # either boolean or fancy integer index
# -> 2053             return self._getitem_array(key)
#    2054         elif isinstance(key, DataFrame):
#    2055             return self._getitem_frame(key)
#
# C:\Users\xiongjun\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_array(self, key)
#    2095             return self.take(indexer, axis=0, convert=False)
#    2096         else:
# -> 2097             indexer = self.ix._convert_to_indexer(key, axis=1)
#    2098             return self.take(indexer, axis=1, convert=True)
#    2099
#
# C:\Users\xiongjun\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\indexing.py in _convert_to_indexer(self, obj, axis, is_setter)
#    1228                 mask = check == -1
#    1229                 if mask.any():
# -> 1230                     raise KeyError('%s not in index' % objarr[mask])
#    1231
#    1232                 return _values_from_object(indexer)
#
# KeyError: "['ld_xc'] not in index"

# %% [markdown]
# ## 低分段人群的规则命中情况

# %%
#低分段人群的规则命中分布
columns1=list(score_data1.columns)
rules1=pd.Series(index=columns1)
for i in columns1:  
         rules1[i]=score_data1[(score_data1.score<=470)& (score_data1[i]==1) ].shape[0]/score_data1[score_data1['score']<=470].shape[0]

# %%
rules1
# Out:
# type               0.144888
# ls_od_b_1y         0.003428
# ls_od_b_2y         0.002722
# xc_overloan        0.987699
# xc_overdue         0.086913
# rv                 0.067251
# rc_idname_multi    0.030954
# rc_relation_cnt    0.055152
# ls_cr              0.000504
# ls_cr_cl           0.002017
# ls_gp              0.012402
# ls_nd              0.016435
# ld_xc              0.298951
# bs_gps5            0.058480
# probability        0.000000
# odds               0.000000
# score              0.000000
# dtype: float64

# %%
#低分段人群的规则命中时的bad_rate
columns1=list(score_data1.columns)
rules2=pd.Series(index=columns1)
for i in columns1:
    if(score_data1[(score_data1.score<=470)& (score_data1[i]==1) ].shape[0]==0):
        rules2[i]=0
    else:
         rules2[i]=score_data1[(score_data1.score<=470)& (score_data1[i]==1)& (score_data1.type==1)].shape[0]/score_data1[(score_data1.score<=470)& (score_data1[i]==1) ].shape[0]

# %%
rules2
# Out:
# type               1.000000
# ls_od_b_1y         0.176471
# ls_od_b_2y         0.185185
# xc_overloan        0.145161
# xc_overdue         0.155452
# rv                 0.134933
# rc_idname_multi    0.153094
# rc_relation_cnt    0.148080
# ls_cr              0.000000
# ls_cr_cl           0.200000
# ls_gp              0.130081
# ls_nd              0.092025
# ld_xc              0.141990
# bs_gps5            0.141379
# probability        0.000000
# odds               0.000000
# score              0.000000
# dtype: float64

# %%
#详情下载
score_data1.to_csv('score_data1.csv')

# %% [markdown]
# ## 高分段人数

# %%
#低分段人群的规则命中分布
columns3=list(score_data1.columns)
rules3=pd.Series(index=columns1)
for i in columns1:  
         rules3[i]=score_data1[(score_data1.score>450)& (score_data1[i]==1) ].shape[0]/score_data1[score_data1['score']>450].shape[0]

# %%
rules3
# Out:
# type               0.056199
# ls_od_b_1y         0.000831
# ls_od_b_2y         0.000185
# xc_overloan        0.154155
# xc_overdue         0.057491
# rv                 0.056799
# rc_idname_multi    0.019656
# rc_relation_cnt    0.031745
# ls_cr              0.088220
# ls_cr_cl           0.306603
# ls_gp              0.028699
# ls_nd              0.253634
# ld_xc              0.452729
# bs_gps5            0.048540
# probability        0.000000
# odds               0.000000
# score              0.000000
# dtype: float64

# %% [markdown]
# ## 测试样本1

# %%
#诺亚点点2018-02/10-02/27数据
#data_test = pd.read_csv('D:\\python\\huabao\\tmp_score_nuoya_variablerank0427_2.csv')
#诺亚点点2018-02/10-02/27数据2
#data_test = pd.read_csv('D:\\python\\huabao\\tmp_score_nuoya_variable0426_2.csv')
#data_test.shape

#诺亚点点数据集时间段：2017-11/01-2017-12/01——首次
data_test = pd.read_csv('D:\\python\\huabao\\tmp_score_nuoya_variablerank0427_3.csv')
data_test.shape
# Out:
# (4475, 59)

# %%
#样本的bad_rate
pitest=data_test[data_test['type']==1].shape[0]/data_test.shape[0]
pitest
# Out:
# 0.07932960893854749

# %% [markdown]
# ### 测试样本区隔力KS

# %%
selected_var ={
    #'cs_size_s':[0],
    #'cs_size_s_ctn_l_rel_m':[0],
 'cs_size_s_ctn_m_rel_m':[0],
 'cs_size_s_ctn_m_rel_l':[0],
 #'cs_size_s_ctn_l_rel_l':[0],
               #'od':[0],
                #'ls_od_b_1y':[0],
                #'ls_od_b_2y':[0],
                #'ls_od_f_6t':[0],
               'xc_behavior':[0],
               'xc_overloan':[0],
               #'lp_p1_xc_overloan':[0],
               'xc_overdue':[0],
               #'xc_record':[0],
               'rv':[0],
                'rc_idname_multi':[0],
                'rc_relation_age':[0],
                'rc_relation_multi':[0],
                'rc_relation_cnt':[0],
               'ls_cr':[0],
               'ls_cr_cl':[0],
               'ls_gp':[0],
               #'ls_gp_cl':[0],
               'ls_nd':[0],
                'ld_gps5_rc':[0],
'ld_add5_rc':[0],
#'ld_add5_xc_ml':[0],
#'ld_add5_xc_m':[0],
#'lp_p1_ld_add5_od':[0],
#'lp_p1_ld_add5_rc':[0],
                 'cg_add5':[0],
               #'bs_gps5':[0],
#'bs_add5_id6plus_dist_c':[0],
#'bs_add5_id6plus_dist_vf':[0],
#'bs_add5_id6plus_dist_vc':[0],
#'lp_p1_ld_idnbr_6plus_xcp':[0],
#'lp_p1_vl_idnbr':[0]
               
              }
#WOE变换
WOE_test = WOE_mapping(data_test,selected_var, target)
test_X = WOE_test.drop(target, axis = 1)
test_X['constant'] = 1
test_Y = WOE_test[target]

#KS值
predict_test_Y = logit.predict(test_X)
KS_calculation(test_Y,predict_test_Y, 40)
# Out:
# C:\Users\xiongjun\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\generic.py:3295: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)
# C:\Users\xiongjun\sc_func.py:124: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df['qt_binning'] = var_bins_series(df[var], bins, side = side)
# 0.20662040202379298

# %%
roc_auc_score(test_Y,predict_test_Y)
# Out:
# 0.60407220019143992

# %% [markdown]
# ## 测试样本分数分布

# %%
import math
score_test=data_test[['type']]
score_test['probability'] = predict_test_Y

#风险odds=15:1时，基本分数为660分
#风险翻倍时，即odds=15:2时，分数降低50分
B = 50/math.log(2, math.e)
A = 500 + B * math.log(1/15,math.e)

score_test['odds'] = (score_test['probability']/(1-score_test['probability']) ).apply(lambda x: math.log(x, math.e))
score_test['score'] = A - B * score_test['odds']
# Out:
# C:\Users\xiongjun\AppData\Local\Continuum\Anaconda3\lib\site-packages\ipykernel\__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# C:\Users\xiongjun\AppData\Local\Continuum\Anaconda3\lib\site-packages\ipykernel\__main__.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\xiongjun\AppData\Local\Continuum\Anaconda3\lib\site-packages\ipykernel\__main__.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
#分数分段
bins=[460,490,500,550]
#bins=10
var_bin_test = variable_binning(score_test, target, var_name, bins, 'bins')
#var_bin.sort_values('Lbound')
# Out:
# C:\Users\xiongjun\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\generic.py:3295: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)
# C:\Users\xiongjun\sc_func.py:124: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df['qt_binning'] = var_bins_series(df[var], bins, side = side)

# %%
binning_plot(var_bin_test)

# %%
var_bin_test['Lift']=var_bin_test['Y_rate']/0.047
var_bin_test['Lift'].plot.bar(secondary_y=True,alpha = 0.8, grid = False)
plt.title('Lift')
plt.show()

# %%
var_bin_test
# Out:
#                  Lbound       Ubound  Totalcnt  PctTotal  Y_count  n_Y_count  \
# qt_binning
# (-inf, 460]  373.465829   459.361193      1662  0.371397      188       1474
# (460, 490]   462.512262   489.455367       158  0.035307       11        147
# (490, 500]   490.591281   499.725972      1980  0.442458      136       1844
# (500, 550]   509.612941   540.027109       603  0.134749       20        583
# (550, +inf)  566.932641  1164.518877        72  0.016089        0         72
#
#                 Y_pct   n_Y_pct    Y_rate       WOE        IV
# qt_binning
# (-inf, 460]  0.529577  0.357767  0.113117  0.392198  0.067384
# (460, 490]   0.030986  0.035680  0.069620 -0.141047  0.000662
# (490, 500]   0.383099  0.447573  0.068687 -0.155547  0.010029
# (500, 550]   0.056338  0.141505  0.033167 -0.920964  0.078436
# (550, +inf)  0.000001  0.017476  0.000000 -9.768568  0.170703

# %% [markdown]
# ## 低分段人群命中规则分布

# %%
import math
score_data_test=data_form[['type',
                'ls_od_b_1y',
                'ls_od_b_2y',
               'xc_overloan',
               'xc_overdue',
               'rv',
               'rc_idname_multi',
                'rc_relation_cnt',
               'ls_cr',
               'ls_cr_cl',
               'ls_gp',
               'ls_nd',
               'ld_xc',
               'bs_gps5']]
score_data_test['probability'] = predict_Y

#风险odds=15:1时，基本分数为660分
#风险翻倍时，即odds=15:2时，分数降低50分
B = 50/math.log(2, math.e)
A = 500 + B * math.log(1/15,math.e)

score_data_test['odds'] = (score_data['probability']/(1-score_data['probability']) ).apply(lambda x: math.log(x, math.e))
score_data_test['score'] = A - B * score_data['odds']

#低分段人群的规则命中分布
columns1=list(score_data_test.columns)
rules1=pd.Series(index=columns1)
for i in columns1:  
         rules1[i]=score_data_test[(score_data_test.score<=470)& (score_data_test[i]==1) ].shape[0]/score_data_test[score_data_test['score']<=470].shape[0]

rules1
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-235-832b963bd2db> in <module>()
#      13                'ls_nd',
#      14                'ld_xc',
# ---> 15                'bs_gps5']]
#      16 score_data_test['probability'] = predict_Y
#      17
#
# C:\Users\xiongjun\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2051         if isinstance(key, (Series, np.ndarray, Index, list)):
#    2052             # either boolean or fancy integer index
# -> 2053             return self._getitem_array(key)
#    2054         elif isinstance(key, DataFrame):
#    2055             return self._getitem_frame(key)
#
# C:\Users\xiongjun\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_array(self, key)
#    2095             return self.take(indexer, axis=0, convert=False)
#    2096         else:
# -> 2097             indexer = self.ix._convert_to_indexer(key, axis=1)
#    2098             return self.take(indexer, axis=1, convert=True)
#    2099
#
# C:\Users\xiongjun\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\indexing.py in _convert_to_indexer(self, obj, axis, is_setter)
#    1228                 mask = check == -1
#    1229                 if mask.any():
# -> 1230                     raise KeyError('%s not in index' % objarr[mask])
#    1231
#    1232                 return _values_from_object(indexer)
#
# KeyError: "['ld_xc'] not in index"

# %% [markdown]
# ## 测试样本稳定性PSI

# %%
def model_psi(var_bin,var_bin_test):
    PSI_in=pd.DataFrame()
    PSI_in['Y_pct1']=var_bin.PctTotal
    PSI_in['Y_pct2']=var_bin_test.PctTotal
    psi_result=pd.DataFrame()
    psi_result['rate1'] = (PSI_in['Y_pct1']/PSI_in['Y_pct2']).map(lambda x:log(x))
    psi_result['rate2'] = (PSI_in['Y_pct1'] - PSI_in['Y_pct2']) * psi_result['rate1']
    psi = psi_result['rate2'].sum()
    return psi_result

# %%
psi_result=model_psi(var_bin,var_bin_test)
psi = psi_result['rate2'].sum()
psi
# Out:
# 0.05396129730923208

# %%
var_bin.PctTotal
# Out:
# qt_binning
# (-inf, 460]    0.325544
# (460, 480]     0.036676
# (480, 500]     0.391496
# (500, 530]     0.138007
# (530, 550]     0.053229
# (550, +inf)    0.055047
# Name: PctTotal, dtype: float64

# %%
var_bin_test.PctTotal
# Out:
# qt_binning
# (-inf, 460]    0.371397
# (460, 490]     0.035307
# (490, 500]     0.442458
# (500, 550]     0.134749
# (550, +inf)    0.016089
# Name: PctTotal, dtype: float64

# %%
psi_result['rate2']
# Out:
# qt_binning
# (-inf, 460]    0.006042
# (460, 480]          NaN
# (480, 500]          NaN
# (500, 530]          NaN
# (530, 550]          NaN
# (550, +inf)    0.047919
# Name: rate2, dtype: float64

# %% [markdown]
# ## 诺亚点点数据测试2

# %%
data_tg = pd.read_csv('D:\\python\\huabao\\tmp_score_nuoya_daihou_test_0326.csv')
#data_tg['type']=1 #加个常数项做type列，方便后面调用函数运算
data_tg.shape
# Out:
# (4565, 15)

# %%
#样本的bad_rate
data_tg[data_tg['type']==1].shape[0]/data_tg.shape[0]
# Out:
# 0.07097480832420591

# %%
data_tg[data_tg['type']==1].shape[0]
# Out:
# 324

# %%
bins_tg =[450,500,520,550]
var_bin_tg = variable_binning(data_tg, target, var_name, bins_tg, 'bins')
# Out:
# C:\Users\xiongjun\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\generic.py:3295: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)
# C:\Users\xiongjun\sc_func.py:124: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df['qt_binning'] = var_bins_series(df[var], bins, side = side)

# %%
binning_plot(var_bin_tg)

# %%
var_bin_tg
# Out:
#              Lbound  Ubound  Totalcnt  PctTotal  Y_count  n_Y_count     Y_pct  \
# qt_binning
# (-inf, 460]     409     460      1722  0.377218      170       1552  0.524691
# (460, 490]      462     490      1038  0.227382       56        982  0.172840
# (490, 530]      495     527      1803  0.394962       98       1705  0.302469
# (530, 540]      540     540         1  0.000219        0          1  0.000001
# (540, 550]      543     543         1  0.000219        0          1  0.000001
#
#               n_Y_pct    Y_rate       WOE        IV
# qt_binning
# (-inf, 460]  0.365951  0.098722  0.360310  0.057196
# (460, 490]   0.231549  0.053950 -0.292429  0.017168
# (490, 530]   0.402028  0.054354 -0.284542  0.028329
# (530, 540]   0.000236  0.000000 -5.462956  0.001283
# (540, 550]   0.000236  0.000000 -5.462956  0.001283

# %%
psi_result=model_psi(var_bin,var_bin_tg)
psi = psi_result['rate2'].sum()
psi
# Out:
# 0.8459501315704256

# %%
4565/533519
# Out:
# 0.008556396304536484

# %%
selected_var ={#'cs':[0,4,5,6,7],
               #'od':[0],
                'ls_od_b_1y':[0],
                'ls_od_b_2y':[0],
                #'ls_od_f_6t':[0],
               #'xc_behavior':[0],
               'xc_overloan':[0],
               'xc_overdue':[0],
               #'xc_record':[0],
               'rv':[0],
               'rc_idname_multi':[0],
                #'rc_relation_age':[0],
                #'rc_relation_multi':[0],
                'rc_relation_cnt':[0],
               'ls_cr':[0],
               'ls_cr_cl':[0],
               #'ls_gp':[0],
               #'ls_gp_cl':[0],
               'ls_nd':[0],
               #'ld_rc':[0],
               'ld_xc':[0],
               'bs_gps5':[0]
              }

#WOE变换
WOE_tg = WOE_mapping(data_tg,selected_var, target)
tg_X = WOE_tg.drop(target, axis = 1)
tg_X['constant'] = 1
tg_Y = WOE_tg[target]

#KS值
predict_tg_Y = logit.predict(tg_X)
KS_calculation(tg_Y,predict_tg_Y, 40)
# Out:
# C:\Users\xiongjun\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\generic.py:3295: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)
# C:\Users\xiongjun\sc_func.py:124: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df['qt_binning'] = var_bins_series(df[var], bins, side = side)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-111-65dc06bdba71> in <module>()
#      30
#      31 #KS值
# ---> 32 predict_tg_Y = logit.predict(tg_X)
#      33 KS_calculation(tg_Y,predict_tg_Y, 40)
#
# C:\Users\xiongjun\AppData\Local\Continuum\Anaconda3\lib\site-packages\statsmodels\base\model.py in predict(self, exog, transform, *args, **kwargs)
#     747             exog = np.atleast_2d(exog)  # needed in count model shape[1]
#     748
# --> 749         return self.model.predict(self.params, exog, *args, **kwargs)
#     750
#     751
#
# C:\Users\xiongjun\AppData\Local\Continuum\Anaconda3\lib\site-packages\statsmodels\discrete\discrete_model.py in predict(self, params, exog, linear)
#     428             exog = self.exog
#     429         if not linear:
# --> 430             return self.cdf(np.dot(exog, params))
#     431         else:
#     432             return np.dot(exog, params)
#
# ValueError: shapes (4565,13) and (14,) not aligned: 13 (dim 1) != 14 (dim 0)

# %%
roc_auc_score(tg_Y,predict_tg_Y)
# Out:
# 0.62409830840035985

# %% [markdown]
# ## 算话评分测试

# %%
data_sh = pd.read_csv('D:\\python\\huabao\\tmp_suanhua_test0330.csv')
#data_tg['type']=1 #加个常数项做type列，方便后面调用函数运算
data_sh.shape
# Out:
# (4156, 7)

# %%
#样本的bad_rate
data_sh[data_sh['type']==1].shape[0]/data_sh.shape[0]
# Out:
# 0.1737247353224254

# %%
data_sh[data_sh['type']==1].shape[0]
# Out:
# 722

# %%
data_sh1_xuni=data_sh[data_sh['product_category']=='余额代偿']

# %%
bins_sh1 =[540,550,560,570,580]
var_sh1='score1'
var_bin_sh1 = variable_binning(data_sh1_xuni, target, var_sh1, bins_sh1, 'bins')
# Out:
# C:\Users\xiongjun\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\generic.py:3295: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)
# C:\Users\xiongjun\sc_func.py:124: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df['qt_binning'] = var_bins_series(df[var], bins, side = side)

# %%
binning_plot(var_bin_sh1)

# %%
var_bin_sh1
# Out:
#              Lbound  Ubound  Totalcnt  PctTotal  Y_count  n_Y_count     Y_pct  \
# qt_binning
# (-inf, 540]     491     540        51  0.100791       20         31  0.222222
# (540, 550]      541     550        52  0.102767       12         40  0.133333
# (550, 560]      551     560        81  0.160079       13         68  0.144444
# (560, 570]      561     570       119  0.235178       16        103  0.177778
# (570, 580]      571     580       125  0.247036       20        105  0.222222
# (580, +inf)     581     607        78  0.154150        9         69  0.100000
#
#               n_Y_pct    Y_rate       WOE        IV
# qt_binning
# (-inf, 540]  0.074519  0.392157  1.092621  0.161383
# (540, 550]   0.096154  0.230769  0.326903  0.012154
# (550, 560]   0.163462  0.160494 -0.123683  0.002352
# (560, 570]   0.247596  0.134454 -0.331265  0.023128
# (570, 580]   0.252404  0.160000 -0.127352  0.003844
# (580, +inf)  0.165865  0.115385 -0.506006  0.033328

# %% [markdown]
# ## score2

# %%
data_sh2=data_sh[data_sh['product_category']=='小额']

# %%
#bins_sh =[530,540,550,560,600]
bins_sh2 =[500,530,540,550,560,580,600]
var_sh2='score2'
var_bin_sh2 = variable_binning(data_sh2, target, var_sh2, bins_sh2, 'bins')
# Out:
# C:\Users\xiongjun\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\generic.py:3295: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)
# C:\Users\xiongjun\sc_func.py:124: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df['qt_binning'] = var_bins_series(df[var], bins, side = side)

# %%
binning_plot(var_bin_sh2)

# %%
var_bin_sh2
# Out:
#              Lbound  Ubound  Totalcnt  PctTotal  Y_count  n_Y_count     Y_pct  \
# qt_binning
# (-inf, 500]     500     500         4  0.005714        0          4  0.000001
# (500, 530]      504     526       152  0.217143       18        134  0.290323
# (530, 540]      531     540        60  0.085714        4         56  0.064516
# (540, 550]      541     546        34  0.048571        4         30  0.064516
# (550, 560]      551     560        98  0.140000       15         83  0.241935
# (560, 580]      561     580       235  0.335714       12        223  0.193548
# (580, 600]      581     600       117  0.167143        9        108  0.145161
#
#               n_Y_pct    Y_rate       WOE        IV
# qt_binning
# (-inf, 500]  0.006270  0.000000 -8.743467  0.054809
# (500, 530]   0.210031  0.118421  0.323736  0.025993
# (530, 540]   0.087774  0.066667 -0.307853  0.007160
# (540, 550]   0.047022  0.117647  0.316301  0.005533
# (550, 560]   0.130094  0.153061  0.620413  0.069388
# (560, 580]   0.349530  0.051064 -0.591061  0.092195
# (580, 600]   0.169279  0.076923 -0.153703  0.003707
